# %%
# %run ./workflow_main

# %%
create_or_update_pipeline(
    config="../config/customer_information.json",
    replace=True
)

# %%
create_or_update_pipeline(
    config="../config/customer_transaction.json",
    replace=True
)
